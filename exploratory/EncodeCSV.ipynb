# %%
import pandas as pd

df = pd.read_csv('card30000.csv')
df.head()
# Out:
#    Unnamed: 0  index  cardId cardType   name  \
# 0           0      1   30001  pokemon   ビードル
# 1           1      2   30002  pokemon   ヤナップ
# 2           2      3   30003  pokemon  ハリマロン
# 3           3      4   30004  pokemon  ハリボーグ
# 4           4      5   30005  pokemon  ブリガロン
#
#                                                  img regulation  setNum  \
# 0  /assets/images/card_images/large/HXY/030001_P_...        HXY     1.0
# 1  /assets/images/card_images/large/HXY/030002_P_...        HXY     2.0
# 2  /assets/images/card_images/large/HXY/030003_P_...        HXY     3.0
# 3  /assets/images/card_images/large/HXY/030004_P_...        HXY     4.0
# 4  /assets/images/card_images/large/HXY/030005_P_...        HXY     5.0
#
#   setCount rarity  ... GXCost GXName  GXDamage  GXDesc weakType weakValue  \
# 0       39    NaN  ...    NaN    NaN       NaN     NaN     fire        ×2
# 1       39    NaN  ...    NaN    NaN       NaN     NaN     fire        ×2
# ...

# %%
df.to_csv('card30000_jp.csv', encoding='utf-8-sig')
